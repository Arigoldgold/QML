# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.optimize import AdamOptimizer, GradientDescentOptimizer

import matplotlib.pyplot as plt


# Set a random seed
np.random.seed(42)

#datasetFig2a, 3.1 (lin3,col1),Hubregtsen2020
# Make a dataset of points inside and outside of a circle
def circle(samples, center=[0.5, 0.5], radius=0.2):
    """
    Generates a dataset of points with 1/0 labels inside a given radius.

    Args:
        samples (int): number of samples to generate
        center (tuple): center of the circle
        radius (float: radius of the circle

    Returns:
        Xvals (array[tuple]): coordinates of points
        yvals (array[int]): classification labels
    """
    Xvals, yvals = [], []

    for i in range(samples):
        x = 2 * (np.random.rand(2)) - 1
        y = 0
        if np.linalg.norm(x - center) < radius:
            y = 1
        Xvals.append(x)
        yvals.append(y)
    return np.array(Xvals, requires_grad=False), np.array(yvals, requires_grad=False)


def plot_data(x, y, fig=None, ax=None):
    """
    Plot data with red/blue values for a binary classification.

    Args:
        x (array[tuple]): array of data points as tuples
        y (array[int]): array of data points as tuples
    """
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    reds = y == 0
    blues = y == 1
    ax.scatter(x[reds, 0], x[reds, 1], c="red", s=25, edgecolor="k")
    ax.scatter(x[blues, 0], x[blues, 1], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")


Xdata, ydata = circle(1500)
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(Xdata, ydata, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.optimize import AdamOptimizer, GradientDescentOptimizer

import matplotlib.pyplot as plt


# Set a random seed
np.random.seed(42)

#datasetFig2a, 3.1 (lin3,col1),Hubregtsen2020
# Make a dataset of points inside and outside of a circle
def circle(samples, center=[0.5, 0.5], radius=0.2):
    """
    Generates a dataset of points with 1/0 labels inside a given radius.

    Args:
        samples (int): number of samples to generate
        center (tuple): center of the circle
        radius (float: radius of the circle

    Returns:
        Xvals (array[tuple]): coordinates of points
        yvals (array[int]): classification labels
    """
    Xvals, yvals = [], []

    for i in range(samples):
        x = 2 * (np.random.rand(2)) - 1
        y = 0
        if np.linalg.norm(x - center) < radius:
            y = 1
        Xvals.append(x)
        yvals.append(y)
    return np.array(Xvals, requires_grad=False), np.array(yvals, requires_grad=False)


def plot_data(x, y, fig=None, ax=None):
    """
    Plot data with red/blue values for a binary classification.

    Args:
        x (array[tuple]): array of data points as tuples
        y (array[int]): array of data points as tuples
    """
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    reds = y == 0
    blues = y == 1
    ax.scatter(x[reds, 0], x[reds, 1], c="red", s=25, edgecolor="k")
    ax.scatter(x[blues, 0], x[blues, 1], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")


Xdata, ydata = circle(15000)
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(Xdata, ydata, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.optimize import AdamOptimizer, GradientDescentOptimizer

import matplotlib.pyplot as plt


# Set a random seed
np.random.seed(42)

#datasetFig2a, 3.2 Hubregtsen2020
# Make a dataset of points inside and outside of two non bordering circles
def circle(samples, center1=[0.25, 0.25], radius1=0.15, center2=[0.75, 0.75], radius2=0.15):
    """
    Generates a dataset of points with 1/0 labels inside a given radius.

    Args:
        samples (int): number of samples to generate
        center (tuple): center of the circle
        radius (float: radius of the circle

    Returns:
        Xvals (array[tuple]): coordinates of points
        yvals (array[int]): classification labels
    """
    Xvals, yvals = [], []

    for i in range(samples):
        x = 2 * (np.random.rand(2)) - 1
        y = 0
        if np.linalg.norm(x - center1) < radius1:
            y = 1
        if np.linalg.norm(x - center2) < radius2:
            y = 1
        Xvals.append(x)
        yvals.append(y)
    return np.array(Xvals, requires_grad=False), np.array(yvals, requires_grad=False)



def plot_data(x, y, fig=None, ax=None):
    """
    Plot data with red/blue values for a binary classification.

    Args:
        x (array[tuple]): array of data points as tuples
        y (array[int]): array of data points as tuples
    """
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    reds = y == 0
    blues = y == 1
    ax.scatter(x[reds, 0], x[reds, 1], c="red", s=25, edgecolor="k")
    ax.scatter(x[blues, 0], x[blues, 1], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")


Xdata, ydata = circle(15000)
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(Xdata, ydata, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %%
import pennylane as qml
from pennylane import numpy as np
from pennylane.optimize import AdamOptimizer, GradientDescentOptimizer

import matplotlib.pyplot as plt


# Set a random seed
np.random.seed(42)

#datasetFig2a, 3.3, Hubregtsen2020
# Make a dataset of points inside and outside of two non bordering circles
def circle(samples, center1=[0.25, 0.25], radius1=0.15, center2=[0.75, 0.75], radius2=0.15, 
          center3=[0.25, 0.75], radius3=0.15, center4=[0.75, 0.25], radius4=0.15):
    """
    Generates a dataset of points with 1/0 labels inside a given radius.

    Args:
        samples (int): number of samples to generate
        center (tuple): center of the circle
        radius (float: radius of the circle

    Returns:
        Xvals (array[tuple]): coordinates of points
        yvals (array[int]): classification labels
    """
    Xvals, yvals = [], []

    for i in range(samples):
        x = 2 * (np.random.rand(2)) - 1
        y = 0
        if np.linalg.norm(x - center1) < radius1:
            y = 1
        if np.linalg.norm(x - center2) < radius2:
            y = 1
        if np.linalg.norm(x - center3) < radius3:
            y = 1
        if np.linalg.norm(x - center4) < radius4:
            y = 1
        Xvals.append(x)
        yvals.append(y)
    return np.array(Xvals, requires_grad=False), np.array(yvals, requires_grad=False)



def plot_data(x, y, fig=None, ax=None):
    """
    Plot data with red/blue values for a binary classification.

    Args:
        x (array[tuple]): array of data points as tuples
        y (array[int]): array of data points as tuples
    """
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    reds = y == 0
    blues = y == 1
    ax.scatter(x[reds, 0], x[reds, 1], c="red", s=25, edgecolor="k")
    ax.scatter(x[blues, 0], x[blues, 1], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")


Xdata, ydata = circle(15000)
fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(Xdata, ydata, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %%
def circle(samples, center=[0.5, 0.5], radius=0.2, center2=[0.75,0.75], radius2=0.2):
    labels = []
    xlist = []
    ylist = []
    
    half_point = False
    while half_point == False:
        x = np.random.rand()
        y = np.random.rand()
        distance = np.sqrt((x-center[0])**2 + (y - center[1])**2)
        if distance > radius:
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
        if len(labels) == int(samples/2):
            break 
    
    half_point = False
    while half_point == False:
        x = np.random.rand()
        y = np.random.rand()
        distance = np.sqrt((x-center[0])**2 + (y - center[1])**2)
        if distance <= radius:
            labels.append(1)
            xlist.append(x)
            ylist.append(y)
        if len(labels) == int(samples):
            break
    
    xvals = np.array(xlist, requires_grad = True)
    yvals = np.array(ylist, requires_grad = True)
    
    return xvals, yvals, labels

import pandas as pd


def plot_data(xvals, yvals,labels, fig=None, ax=None):
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    #reds = labels == -1
    #blues = labels == 1    ""="" = zuweisung ""=="" = überprüfung auf gleichheiht
    
    df = pd.DataFrame()
    df['x'] = xvals
    df['y'] = yvals
    df['labels'] = labels
    print(df.head())
    
    df_minus_one = df[df['labels']==-1]
    df_plus_one = df[df['labels']==1]
    
    #print(df_plus_one.head())
    #print(df_minus_one.shape)
    
    ax.scatter(df_minus_one['x'], df_minus_one['y'], c="red", s=25, edgecolor="k")
    ax.scatter(df_plus_one['x'], df_plus_one['y'], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    
    

xvals, yvals, labels = circle(1500)

print(xvals.shape)
print(yvals.shape)
print(len(labels))

fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(xvals, yvals, labels, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()
# Out:
# (1500,)
# (1500,)
# 1500
#           x         y  labels
# 0  0.964499  0.218978      -1
# 1  0.587856  0.700210      -1
# 2  0.825564  0.406971      -1
# 3  0.686922  0.303201      -1
# 4  0.435476  0.895627      -1

# %%
def circle(samples, center=[0.25, 0.25], radius=0.2, center2=[0.75,0.75]):
    labels = []
    xlist = []
    ylist = []
    
    half_point = False
    while half_point == False:
        x = np.random.rand()
        y = np.random.rand()
        distance = np.sqrt((x-center[0])**2 + (y - center[1])**2)
        distance2 = np.sqrt((x-center2[0])**2 + (y - center2[1])**2)
        if distance > radius:
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
        if distance2 > radius:
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
        if len(labels) == int(samples/2):
            break 
    
    half_point = False
    while half_point == False:
        x = np.random.rand()
        y = np.random.rand()
        distance = np.sqrt((x-center[0])**2 + (y - center[1])**2)
        distance2 = np.sqrt((x-center2[0])**2 + (y - center2[1])**2)
        if distance <= radius:
            labels.append(1)
            xlist.append(x)
            ylist.append(y)
        if distance2 <= radius:
            labels.append(1)
            xlist.append(x)
            ylist.append(y)
        if len(labels) == int(samples):
            break
    
    xvals = np.array(xlist, requires_grad = True)
    yvals = np.array(ylist, requires_grad = True)
    
    return xvals, yvals, labels

import pandas as pd


def plot_data(xvals, yvals,labels, fig=None, ax=None):
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    #reds = labels == -1
    #blues = labels == 1    ""="" = zuweisung ""=="" = überprüfung auf gleichheiht
    
    df = pd.DataFrame()
    df['x'] = xvals
    df['y'] = yvals
    df['labels'] = labels
    print(df.head())
    
    df_minus_one = df[df['labels']==-1]
    df_plus_one = df[df['labels']==1]
    
    #print(df_plus_one.head())
    #print(df_minus_one.shape)
    
    ax.scatter(df_minus_one['x'], df_minus_one['y'], c="red", s=25, edgecolor="k")
    ax.scatter(df_plus_one['x'], df_plus_one['y'], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    
    

xvals, yvals, labels = circle(1500)

print(xvals.shape)
print(yvals.shape)
print(len(labels))

fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(xvals, yvals, labels, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()
# Out:
# (1500,)
# (1500,)
# 1500
#           x         y  labels
# 0  0.380370  0.465582      -1
# 1  0.380370  0.465582      -1
# 2  0.357632  0.410675      -1
# 3  0.314977  0.077641      -1
# 4  0.037346  0.174106      -1

# %%
def circle(samples, center=[0.25, 0.25], radius=0.2, center2=[0.75,0.75]):
    labels = []
    xlist = []
    ylist = []
    
    half_point = False
    while half_point == False:
        x = np.random.rand()
        y = np.random.rand()
        distance = np.sqrt((x-center[0])**2 + (y - center[1])**2)
        distance2 = np.sqrt((x-center2[0])**2 + (y - center2[1])**2)
        if distance > radius:
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
        if distance2 > radius:
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
        if len(labels) == int(samples/2):
            break 
    
    half_point = False
    while half_point == False:
        x = np.random.rand()
        y = np.random.rand()
        distance = np.sqrt((x-center[0])**2 + (y - center[1])**2)
        distance2 = np.sqrt((x-center2[0])**2 + (y - center2[1])**2)
        if distance <= radius:
            labels.append(1)
            xlist.append(x)
            ylist.append(y)
        if distance2 <= radius:
            labels.append(1)
            xlist.append(x)
            ylist.append(y)
        if len(labels) == int(samples):
            break
    
    xvals = np.array(xlist, requires_grad = True)
    yvals = np.array(ylist, requires_grad = True)
    
    return xvals, yvals, labels

import pandas as pd


def plot_data(xvals, yvals,labels, fig=None, ax=None):
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    #reds = labels == -1
    #blues = labels == 1    ""="" = zuweisung ""=="" = überprüfung auf gleichheiht
    
    df = pd.DataFrame()
    df['x'] = xvals
    df['y'] = yvals
    df['labels'] = labels
    print(df.head())
    
    df_minus_one = df[df['labels']==-1]
    df_plus_one = df[df['labels']==1]
    
    #print(df_plus_one.head())
    #print(df_minus_one.shape)
    
    ax.scatter(df_minus_one['x'], df_minus_one['y'], c="red", s=25, edgecolor="k")
    ax.scatter(df_plus_one['x'], df_plus_one['y'], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    
    

xvals, yvals, labels = circle(1500)

print(xvals.shape)
print(yvals.shape)
print(len(labels))

fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(xvals, yvals, labels, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()
# Out:
# (1500,)
# (1500,)
# 1500
#           x         y  labels
# 0  0.379227  0.487224      -1
# 1  0.379227  0.487224      -1
# 2  0.173535  0.788337      -1
# 3  0.173535  0.788337      -1
# 4  0.860668  0.248165      -1

# %%
def circle(samples, center=[0.25, 0.25], radius=0.2, center2=[0.75,0.75], center3=[0.25,0.75], center4=[0.75,0.25]):
    labels = []
    xlist = []
    ylist = []
    
    half_point = False
    while half_point == False:
        x = np.random.rand()
        y = np.random.rand()
        distance = np.sqrt((x-center[0])**2 + (y - center[1])**2)
        distance2 = np.sqrt((x-center2[0])**2 + (y - center2[1])**2)
        distance3 = np.sqrt((x-center3[0])**2 + (y - center3[1])**2)
        distance4 = np.sqrt((x-center4[0])**2 + (y - center4[1])**2)
        if distance > radius:
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
        if distance2 > radius:
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
        if distance3 > radius:
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
        if distance4 > radius:
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
        if len(labels) == int(samples/2):
            break 
    
    half_point = False
    while half_point == False:
        x = np.random.rand()
        y = np.random.rand()
        distance = np.sqrt((x-center[0])**2 + (y - center[1])**2)
        distance2 = np.sqrt((x-center2[0])**2 + (y - center2[1])**2)
        distance3 = np.sqrt((x-center3[0])**2 + (y - center3[1])**2)
        distance4 = np.sqrt((x-center4[0])**2 + (y - center4[1])**2)
        if distance <= radius:
            labels.append(1)
            xlist.append(x)
            ylist.append(y)
        if distance2 <= radius:
            labels.append(1)
            xlist.append(x)
            ylist.append(y)
        if distance3 <= radius:
            labels.append(1)
            xlist.append(x)
            ylist.append(y)
        if distance4 <= radius:
            labels.append(1)
            xlist.append(x)
            ylist.append(y)
        if len(labels) == int(samples):
            break
    
    xvals = np.array(xlist, requires_grad = True)
    yvals = np.array(ylist, requires_grad = True)
    
    return xvals, yvals, labels

import pandas as pd


def plot_data(xvals, yvals,labels, fig=None, ax=None):
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    #reds = labels == -1
    #blues = labels == 1    ""="" = zuweisung ""=="" = überprüfung auf gleichheiht
    
    df = pd.DataFrame()
    df['x'] = xvals
    df['y'] = yvals
    df['labels'] = labels
    print(df.head())
    
    df_minus_one = df[df['labels']==-1]
    df_plus_one = df[df['labels']==1]
    
    #print(df_plus_one.head())
    #print(df_minus_one.shape)
    
    ax.scatter(df_minus_one['x'], df_minus_one['y'], c="red", s=25, edgecolor="k")
    ax.scatter(df_plus_one['x'], df_plus_one['y'], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    
    

xvals, yvals, labels = circle(1500)

print(xvals.shape)
print(yvals.shape)
print(len(labels))

fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(xvals, yvals, labels, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-8-d0f7bf099c98> in <module>
#      91
#      92
# ---> 93 xvals, yvals, labels = circle(1500)
#      94
#      95 print(xvals.shape)
#
# <ipython-input-8-d0f7bf099c98> in circle(samples, center, radius, center2, center3, center4)
#       6     half_point = False
#       7     while half_point == False:
# ----> 8         x = np.random.rand()
#       9         y = np.random.rand()
#      10         distance = np.sqrt((x-center[0])**2 + (y - center[1])**2)
#
# /usr/local/anaconda3/lib/python3.8/site-packages/pennylane/numpy/wrapper.py in _wrapped(*args, **kwargs)
#      73
#      74         # evaluate the original object
# ---> 75         res = obj(*args, **kwargs)
#      76
#      77         if isinstance(res, _np.ndarray):
#
# /usr/local/anaconda3/lib/python3.8/site-packages/autograd/tracer.py in f_wrapped(*args, **kwargs)
#      46             return new_box(ans, trace, node)
#      47         else:
# ---> 48             return f_raw(*args, **kwargs)
#      49     f_wrapped.fun = f_raw
#      50     f_wrapped._is_autograd_primitive = True
#
# KeyboardInterrupt:

# %%
def isnotcontainedinanycircle(centers, radius, x, y):
    for center in centers:
        if np.sqrt((x-center[0])**2 + (y - center[1])**2) < radius:
            return False
    return True

def circle(samples, centers=[[0.75,0.75],[0.25, 0.25]], radius=0.15):
    labels = []
    xlist = []
    ylist = []
    
    while len(labels) < int(samples/2):
        x = np.random.rand()
        y = np.random.rand()
        if isnotcontainedinanycircle(centers, radius, x, y):
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
      
            
    while len(labels) < samples:
        x = np.random.rand()
        y = np.random.rand()
        if not isnotcontainedinanycircle(centers, radius, x, y):
            labels.append(1)
            xlist.append(x)
            ylist.append(y) 
    
    xvals = np.array(xlist, requires_grad = True)
    yvals = np.array(ylist, requires_grad = True)
    
    return xvals, yvals, labels

import pandas as pd


def plot_data(xvals, yvals,labels, fig=None, ax=None):
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    #reds = labels == -1
    #blues = labels == 1    ""="" = zuweisung ""=="" = überprüfung auf gleichheiht
    
    df = pd.DataFrame()
    df['x'] = xvals
    df['y'] = yvals
    df['labels'] = labels
    print(df.head())
    
    df_minus_one = df[df['labels']==-1]
    df_plus_one = df[df['labels']==1]
    
    ax.scatter(df_minus_one['x'], df_minus_one['y'], c="red", s=25, edgecolor="k")
    ax.scatter(df_plus_one['x'], df_plus_one['y'], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    
    

xvals, yvals, labels = circle(1500)

print(xvals.shape)
print(yvals.shape)
print(len(labels))

fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(xvals, yvals, labels, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()

# %%
def isnotcontainedinanycircle(centers, radius, x, y):
    for center in centers:
        if np.sqrt((x-center[0])**2 + (y - center[1])**2) < radius:
            return False
    return True

def circle(samples, centers=[[0.25, 0.75],[0.75, 0.25],[0.75,0.75],[0.25, 0.25]], radius=0.15):
    labels = []
    xlist = []
    ylist = []
    
    while len(labels) < int(samples/2):
        x = np.random.rand()
        y = np.random.rand()
        if isnotcontainedinanycircle(centers, radius, x, y):
            labels.append(-1)
            xlist.append(x)
            ylist.append(y)
                 
    while len(labels) < samples:
        x = np.random.rand()
        y = np.random.rand()
        if not isnotcontainedinanycircle(centers, radius, x, y):
            labels.append(1)
            xlist.append(x)
            ylist.append(y) 
    
    xvals = np.array(xlist, requires_grad = True)
    yvals = np.array(ylist, requires_grad = True)
    
    return xvals, yvals, labels





import pandas as pd


def plot_data(xvals, yvals,labels, fig=None, ax=None):
    if fig == None:
        fig, ax = plt.subplots(1, 1, figsize=(5, 5))
    #reds = labels == -1
    #blues = labels == 1    
    
    df = pd.DataFrame()
    df['x'] = xvals
    df['y'] = yvals
    df['labels'] = labels
    print(df.head())
    
    df_minus_one = df[df['labels']==-1]
    df_plus_one = df[df['labels']==1]
    
    ax.scatter(df_minus_one['x'], df_minus_one['y'], c="red", s=25, edgecolor="k")
    ax.scatter(df_plus_one['x'], df_plus_one['y'], c="blue", s=25, edgecolor="k")
    ax.set_xlabel("$x_1$")
    ax.set_ylabel("$x_2$")
    
    

xvals, yvals, labels = circle(1500)

print(xvals.shape)
print(yvals.shape)
print(len(labels))

fig, ax = plt.subplots(1, 1, figsize=(4, 4))
plot_data(xvals, yvals, labels, fig=fig, ax=ax)
plt.xlim(0,1)
plt.ylim(0,1)
plt.show()
# Out:
# (1500,)
# (1500,)
# 1500
#           x         y  labels
# 0  0.401577  0.558413      -1
# 1  0.057413  0.761755      -1
# 2  0.218989  0.991349      -1
# 3  0.131837  0.556139      -1
# 4  0.828208  0.400208      -1
